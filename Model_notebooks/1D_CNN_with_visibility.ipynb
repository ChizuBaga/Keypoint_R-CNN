# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import MinMaxScaler, minmax_scale
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from torch.optim.lr_scheduler import LinearLR, CosineAnnealingLR, SequentialLR
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import zipfile
#from google.colab import drive

# %%
def set_seed_strict(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        
        torch.backends.cudnn.benchmark = False
    torch.use_deterministic_algorithms(True, warn_only=True)


set_seed_strict(42)

# %% [markdown]
# # **Data Loading & Data Preparation**

# %%
"""
drive.mount('/content/drive')
zip_path = '/content/drive/MyDrive/datasets_with_visibility.zip'
csv = {}

with zipfile.ZipFile(zip_path, 'r') as z:
    # Get a list of all files in the zip
    all_files = z.namelist()

    # Filter for only CSV files
    csv_files = [f for f in all_files if f.endswith('.csv') and not f.startswith('__MACOSX')]

    for csv_path in csv_files:
        with z.open(csv_path) as f:
            # Use the filename as the key
            file_name = csv_path.split('/')[-1]
            csv[file_name] = pd.read_csv(f)
            print(f"Loaded: {csv_path}")
"""
# Out:
# '\ndrive.mount(\'/content/drive\')\nzip_path = \'/content/drive/MyDrive/datasets_with_visibility.zip\'\ncsv = {}\n\nwith zipfile.ZipFile(zip_path, \'r\') as z:\n    # Get a list of all files in the zip\n    all_files = z.namelist()\n\n    # Filter for only CSV files\n    csv_files = [f for f in all_files if f.endswith(\'.csv\') and not f.startswith(\'__MACOSX\')]\n\n    for csv_path in csv_files:\n        with z.open(csv_path) as f:\n            # Use the filename as the key\n            file_name = csv_path.split(\'/\')[-1]\n            csv[file_name] = pd.read_csv(f)\n            print(f"Loaded: {csv_path}")\n'

# %% [markdown]
# ## **Load Datasets**

# %%
"""
train_df = csv['keypoint_train_data.csv']
valid_df = csv['keypoint_valid_data.csv']
test_df = csv['keypoint_test_data.csv']
"""

train_df = pd.read_csv('keypoint_train_data.csv')
valid_df = pd.read_csv('keypoint_valid_data.csv')
test_df = pd.read_csv('keypoint_test_data.csv')

# %% [markdown]
# ## **Shift [cat_id] from 1:2 to 0:1**

# %%
train_df['cat_id'] = train_df['cat_id'] - 1
valid_df['cat_id'] = valid_df['cat_id'] - 1
test_df['cat_id'] = test_df['cat_id'] - 1

train_df.head()
# Out:
#    image_id  cat_id      nose_x      nose_y  nose_v  left_eye_x  left_eye_y  \
# 0         0       0  381.166412  125.746658     1.0  381.166412  114.563187
# 1         1       1  368.703186  200.296249     1.0  373.500092  186.699783
# 2         2       1  254.824997  367.375610     1.0  227.677002  378.566132
# 3         3       1  423.618744  145.820709     1.0  431.610840  129.045349
# 4         4       1  241.430283  215.023224     1.0  243.826614  201.425888
#
#    left_eye_v  right_eye_x  right_eye_y  ...  left_knee_v  right_knee_x  \
# 0         1.0   373.181763   114.563187  ...          1.0    504.129974
# 1         1.0   371.901123   187.499557  ...          1.0    349.515381
# 2         1.0   227.677002   378.566132  ...          0.0      0.000000
# 3         1.0   426.815582   129.045349  ...          1.0    298.142303
# 4         1.0   242.229050   203.025558  ...          1.0    223.857300
#
#    right_knee_y  right_knee_v  left_ankle_x  left_ankle_y  left_ankle_v  \
# 0    394.948792           1.0    526.487000    553.115051           1.0
# 1    372.251770           1.0    328.728607    556.204163           1.0
# 2      0.000000           0.0      0.000000      0.000000           0.0
# 3    403.841614           1.0    148.689423    582.778748           1.0
# 4    387.789368           1.0    203.089233    563.754883           1.0
#
#    right_ankle_x  right_ankle_y  right_ankle_v
# 0     527.285461     553.115051            1.0
# 1     362.307220     524.212402            1.0
# 2       0.000000       0.000000            0.0
# 3     256.583221     536.446777            1.0
# 4     239.033966     539.759583            1.0
#
# [5 rows x 53 columns]

# %% [markdown]
# ## **Data Normalization**

# %%
def minmax_normalise(df, variations: str, scaler=None, is_train: bool=True):

    df_normalized = df.copy()
    
    coord_cols = df_normalized.columns.drop(['image_id', 'cat_id'])

    ####################################
    # Generated from Gemini
    ####################################
    visibility_cols = [col for col in coord_cols if col.endswith('_v')]
    xy_cols = [col for col in coord_cols if not col.endswith('_v')]
    ####################################
    # End
    ####################################

    for visibility_col in visibility_cols:
        col_name = visibility_col.replace('_v', '')
        X_col = f"{col_name}_x"
        y_col = f"{col_name}_y"
        
        mask = df_normalized[visibility_col] == 0.0
        df_normalized.loc[mask, [X_col, y_col]] = np.nan
    
    
    if variations=="col_wise":
        print("Using MinMaxScaler")
        if is_train:
            scaler = MinMaxScaler()
            df_normalized[xy_cols] = scaler.fit_transform(df_normalized[xy_cols])
            
        else:
            if scaler is None:
                print("No scaler given!")
            
            df_normalized[xy_cols] = scaler.transform(df_normalized[xy_cols])
    
    # Note: minmax_scale, scaling row wise is abandon, irrelevant
    elif variations=="row_wise":
        print("Using minmax_scale")
        scaled_array = minmax_scale(df_normalized[xy_cols], axis=1)
        df_normalized[xy_cols] = scaled_array
    
    df_normalized[xy_cols] = df_normalized[xy_cols].fillna(0.0)

    if variations=="col_wise" and is_train:
        return df_normalized, scaler
    else:
        return df_normalized

# %%
def manual_normalisation(df):
    df_normalized = df.copy()
    coord_cols = df_normalized.columns.drop(['image_id', 'cat_id'])

    for index, row in df_normalized.iterrows():
        raw_coords = row[coord_cols].values.astype(np.float32)
        
        tensor_coords = torch.tensor(raw_coords).view(17, 3)
        
        normalized_tensor = normalize_coco_posture_safe(tensor_coords)
        
        flat_normalized_coords = normalized_tensor.view(-1).numpy()
        
        df_normalized.loc[index, coord_cols] = flat_normalized_coords
        
    return df_normalized

def normalize_coco_posture_safe(pos_tensor):
    coordinates = pos_tensor[:, :2].clone()
    vis = pos_tensor[:, 2].clone()
    
    valid_mask = vis > 0.0 
    
    if not valid_mask.any():
        return pos_tensor
    
    l_hip_valid = valid_mask[11].item()
    r_hip_valid = valid_mask[12].item()
    
    if l_hip_valid and r_hip_valid:
        root = (coordinates[11] + coordinates[12]) / 2.0
    elif l_hip_valid:
        root = coordinates[11]
    elif r_hip_valid:
        root = coordinates[12]
    else:
        l_sho_valid = valid_mask[5].item()
        r_sho_valid = valid_mask[6].item()
        if l_sho_valid and r_sho_valid:
            root = (coordinates[5] + coordinates[6]) / 2.0
        else:
            root = torch.tensor([0.0, 0.0], device=coordinates.device)

    coordinates[valid_mask] = coordinates[valid_mask] - root

    ###############################
    # Generated from Gen AI
    ###############################
    
    min_vals = coordinates[valid_mask].min(dim=0)[0]
    max_vals = coordinates[valid_mask].max(dim=0)[0]
    
    ranges = max_vals - min_vals

    global_scale = ranges.max()
    
    coordinates[valid_mask] = coordinates[valid_mask] / (global_scale + 1e-6)
    
    final_tensor = torch.cat([coordinates, vis.unsqueeze(1)], dim=1)
    ###############################
    # End
    ###############################

    return final_tensor

# %%
def normalise(df, is_train:bool, type: str=None, scaler=None, variation: str=None):
    if type == "manual":
        df_normalized = manual_normalisation(df)
        return df_normalized
        
    elif type == "auto" and variation in ["row_wise", "col_wise"]:
        
        if is_train and variation == "col_wise":
            df_normalized, scaler = minmax_normalise(df=df, variations=variation, scaler=scaler, is_train=is_train)
            return df_normalized, scaler
            
        else:
            df_normalized = minmax_normalise(df=df, variations=variation, scaler=scaler, is_train=is_train)
            return df_normalized
            
    else:
        print("Unknown type or variation given.")
        raise ValueError("Normalization failed due to invalid arguments.")

# %%
# manual normalization
train_df_norm = normalise(train_df, is_train=False, type="manual")
valid_df_norm = normalise(valid_df, is_train=False, type="manual")
test_df_norm = normalise(test_df, is_train=False, type="manual")

"""
# MinMaxScaler
train_df_norm, fitted_scaler = normalise(df=train_df, is_train=True, type="auto", variation="col_wise")
valid_df_norm = normalise(df=valid_df, is_train=False, type="auto", scaler=fitted_scaler, variation="col_wise")
test_df_norm = normalise(df=test_df, is_train=False, type="auto", scaler=fitted_scaler, variation="col_wise")
"""



# minmax_scale
# train_df_norm = normalise(df=train_df, is_train=False, type="auto", variation="row_wise")
# valid_df_norm = normalise(df=valid_df, is_train=False, type="auto", variation="row_wise")
# test_df_norm = normalise(df=test_df, is_train=False, type="auto", variation="row_wise")
# Out:
# '\n# MinMaxScaler\ntrain_df_norm, fitted_scaler = normalise(df=train_df, is_train=True, type="auto", variation="col_wise")\nvalid_df_norm = normalise(df=valid_df, is_train=False, type="auto", scaler=fitted_scaler, variation="col_wise")\ntest_df_norm = normalise(df=test_df, is_train=False, type="auto", scaler=fitted_scaler, variation="col_wise")\n'

# %% [markdown]
# ## **Dataset Class**

# %%
class KeypointDataset(Dataset):
  def __init__(self, df):
    X_np = df.drop(['image_id', 'cat_id'], axis =1).values
    y_np = df['cat_id'].values

    # Reshape from (N, 34) to (N, 17, 3)
    N = X_np.shape[0]
    X_reshape = X_np.reshape(N, 17, 3)

    X_transpose = np.transpose(X_reshape, (0, 2, 1))

    # Convert to tensors
    self.X = torch.tensor(X_transpose, dtype=torch.float32)
    self.y = torch.tensor(y_np,dtype=torch.float32).unsqueeze(1)

  def __len__(self):
    return len(self.X)

  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

# %%
train_dataset = KeypointDataset(train_df_norm)
valid_dataset = KeypointDataset(valid_df_norm)
test_dataset = KeypointDataset(test_df_norm)

# %% [markdown]
# ## **Batch Loading with DataLoader**

# %%
BATCH_SIZE = 64

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False)

# %%
X_batch, y_batch = next(iter(train_loader))
print("Batch X shape:", X_batch.shape)
print("Batch y shape:", y_batch.shape)
# Out:
# Batch X shape: torch.Size([64, 3, 17])
# Batch y shape: torch.Size([64, 1])

# %% [markdown]
# # **Model Class**

# %%
class CNN1d(nn.Module):
  def __init__(self):
    super().__init__()

    self.conv1 = nn.Conv1d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
    self.bn1 = nn.BatchNorm1d(32)
    self.pool1 = nn.MaxPool1d(kernel_size=2)

    ####################################
    # Generated from Gemini
    ####################################
    self.spatial_dropout1 = nn.Dropout1d(p=0.2)
    ####################################
    # End
    ####################################

    self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
    self.bn2 = nn.BatchNorm1d(64)
    self.pool2 = nn.MaxPool1d(kernel_size=2)

    ####################################
    # Generated from Gemini
    ####################################
    self.spatial_dropout2 = nn.Dropout1d(p=0.2)

    self.global_avg_pool = nn.AdaptiveAvgPool1d(1)
    ####################################
    # End
    ####################################

    self.fc1 = nn.Linear(64, 32)
    self.dropout = nn.Dropout(p=0.6)
    self.fc2 = nn.Linear(32, 1)

  def forward(self, x):
    x = self.conv1(x)
    x = self.bn1(x)
    x = F.relu(x)
    x = self.pool1(x)

    x = self.spatial_dropout1(x)

    x = self.conv2(x)
    x = self.bn2(x)
    x = F.relu(x)
    x = self.pool2(x)

    x = self.spatial_dropout2(x)

    x = self.global_avg_pool(x)
    x = torch.flatten(x, 1)

    x = self.fc1(x)
    x = F.relu(x)
    x = self.dropout(x)

    x = self.fc2(x)

    return x

# %%
model = CNN1d()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(model)
# Out:
# CNN1d(
#   (conv1): Conv1d(3, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (spatial_dropout1): Dropout1d(p=0.2, inplace=False)
#   (conv2): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (spatial_dropout2): Dropout1d(p=0.2, inplace=False)
#   (global_avg_pool): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (fc2): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
def calculate_accuracy(y_pred, y_true):
    # Apply sigmoid to the raw logits to get probabilities
    probabilities = torch.sigmoid(y_pred)
    predicted_classes = torch.round(probabilities)
    # Count how many match the true labels
    correct = (predicted_classes == y_true).sum().float()
    # Calculate percentage
    return correct / y_true.shape[0]

# %% [markdown]
# # **Training Loop**

# %%
epochs = 200
warmup_epochs = 5

best_val_loss = float('inf')
patience = 30
patience_count = 0
checkpoint_path = "1D-CNN.pth"

train_losses = []
train_accs = []
valid_losses = []
valid_accs = []

loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
warmup_scheduler = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_epochs)
decay_scheduler = CosineAnnealingLR(optimizer, T_max=(epochs - warmup_epochs), eta_min=1e-6)

scheduler = SequentialLR(
    optimizer,
    schedulers=[warmup_scheduler, decay_scheduler],
    milestones=[warmup_epochs]
)

for epoch in range(epochs):
  model.train()

  train_loss = 0.0
  train_acc = 0.0

  for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()

        predictions = model(X_batch)

        loss = loss_function(predictions, y_batch)

        loss.backward()

        optimizer.step()

        train_loss += loss.item()
        train_acc += calculate_accuracy(predictions, y_batch).item()

  scheduler.step()

  avg_train_loss = train_loss / len(train_loader)
  avg_train_acc = train_acc / len(train_loader)

  model.eval()
  valid_loss = 0.0
  valid_acc = 0.0

  with torch.no_grad():
      for X_batch, y_batch in valid_loader:
          X_batch, y_batch = X_batch.to(device), y_batch.to(device)

          predictions = model(X_batch)
          loss = loss_function(predictions, y_batch)

          valid_loss += loss.item()
          valid_acc += calculate_accuracy(predictions, y_batch).item()

  avg_valid_loss = valid_loss / len(valid_loader)
  avg_valid_acc = valid_acc / len(valid_loader)

  train_losses.append(avg_train_loss)
  train_accs.append(avg_train_acc)
  valid_losses.append(avg_valid_loss)
  valid_accs.append(avg_valid_acc)

  print(f"Epoch [{epoch+1:02d}/{epochs}] "
          f"| Train Loss: {avg_train_loss:.4f} | Train Acc: {avg_train_acc*100:.2f}% "
          f"| Valid Loss: {avg_valid_loss:.4f} | Valid Acc: {avg_valid_acc*100:.2f}%")

  if avg_valid_loss < best_val_loss:
      print(f"Valid loss improved. Saving checkpoint to {checkpoint_path}")
      best_val_loss = avg_valid_loss
      patience_counter = 0
      torch.save(model.state_dict(), checkpoint_path)
  else:
      patience_counter += 1
      print(f"Patience: {patience_counter}/{patience}")
      if patience_counter >= patience:
          print("Early Stopping triggered")
          break

print("Training Complete.")
# Out:
# Epoch [01/200] | Train Loss: 0.6935 | Train Acc: 50.06% | Valid Loss: 0.6952 | Valid Acc: 48.49%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [02/200] | Train Loss: 0.6896 | Train Acc: 51.70% | Valid Loss: 0.6852 | Valid Acc: 53.19%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [03/200] | Train Loss: 0.6785 | Train Acc: 57.70% | Valid Loss: 0.6727 | Valid Acc: 64.28%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [04/200] | Train Loss: 0.6630 | Train Acc: 60.06% | Valid Loss: 0.6575 | Valid Acc: 67.80%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [05/200] | Train Loss: 0.6441 | Train Acc: 62.78% | Valid Loss: 0.6410 | Valid Acc: 68.97%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [06/200] | Train Loss: 0.6454 | Train Acc: 63.60% | Valid Loss: 0.6099 | Valid Acc: 71.19%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [07/200] | Train Loss: 0.6251 | Train Acc: 67.93% | Valid Loss: 0.5972 | Valid Acc: 71.84%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [08/200] | Train Loss: 0.5968 | Train Acc: 70.89% | Valid Loss: 0.5771 | Valid Acc: 69.76%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [09/200] | Train Loss: 0.5818 | Train Acc: 70.31% | Valid Loss: 0.5752 | Valid Acc: 68.59%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [10/200] | Train Loss: 0.5731 | Train Acc: 71.89% | Valid Loss: 0.5562 | Valid Acc: 70.94%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [11/200] | Train Loss: 0.5750 | Train Acc: 70.94% | Valid Loss: 0.5534 | Valid Acc: 69.24%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [12/200] | Train Loss: 0.5815 | Train Acc: 70.51% | Valid Loss: 0.5514 | Valid Acc: 70.28%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [13/200] | Train Loss: 0.5835 | Train Acc: 73.06% | Valid Loss: 0.5454 | Valid Acc: 70.41%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [14/200] | Train Loss: 0.5672 | Train Acc: 72.77% | Valid Loss: 0.5365 | Valid Acc: 72.24%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [15/200] | Train Loss: 0.5488 | Train Acc: 73.05% | Valid Loss: 0.5271 | Valid Acc: 74.33%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [16/200] | Train Loss: 0.5472 | Train Acc: 73.71% | Valid Loss: 0.5293 | Valid Acc: 71.32%
# Patience: 1/30
# Epoch [17/200] | Train Loss: 0.5351 | Train Acc: 74.17% | Valid Loss: 0.5298 | Valid Acc: 71.07%
# Patience: 2/30
# Epoch [18/200] | Train Loss: 0.5404 | Train Acc: 74.96% | Valid Loss: 0.5186 | Valid Acc: 75.76%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [19/200] | Train Loss: 0.5340 | Train Acc: 73.90% | Valid Loss: 0.5015 | Valid Acc: 76.54%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [20/200] | Train Loss: 0.5326 | Train Acc: 74.27% | Valid Loss: 0.5049 | Valid Acc: 76.41%
# Patience: 1/30
# Epoch [21/200] | Train Loss: 0.5116 | Train Acc: 76.07% | Valid Loss: 0.4923 | Valid Acc: 75.62%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [22/200] | Train Loss: 0.5252 | Train Acc: 75.44% | Valid Loss: 0.4886 | Valid Acc: 75.89%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [23/200] | Train Loss: 0.5173 | Train Acc: 75.52% | Valid Loss: 0.4964 | Valid Acc: 74.19%
# Patience: 1/30
# Epoch [24/200] | Train Loss: 0.5081 | Train Acc: 76.51% | Valid Loss: 0.4757 | Valid Acc: 76.41%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [25/200] | Train Loss: 0.5018 | Train Acc: 76.19% | Valid Loss: 0.4917 | Valid Acc: 76.93%
# Patience: 1/30
# Epoch [26/200] | Train Loss: 0.4903 | Train Acc: 77.81% | Valid Loss: 0.4912 | Valid Acc: 74.19%
# Patience: 2/30
# Epoch [27/200] | Train Loss: 0.5019 | Train Acc: 77.26% | Valid Loss: 0.4841 | Valid Acc: 76.28%
# Patience: 3/30
# Epoch [28/200] | Train Loss: 0.5100 | Train Acc: 76.70% | Valid Loss: 0.4759 | Valid Acc: 77.58%
# Patience: 4/30
# Epoch [29/200] | Train Loss: 0.4878 | Train Acc: 77.24% | Valid Loss: 0.4535 | Valid Acc: 80.32%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [30/200] | Train Loss: 0.4798 | Train Acc: 79.27% | Valid Loss: 0.4435 | Valid Acc: 80.84%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [31/200] | Train Loss: 0.4941 | Train Acc: 77.34% | Valid Loss: 0.4562 | Valid Acc: 77.84%
# Patience: 1/30
# Epoch [32/200] | Train Loss: 0.4851 | Train Acc: 77.22% | Valid Loss: 0.4789 | Valid Acc: 76.41%
# Patience: 2/30
# Epoch [33/200] | Train Loss: 0.4825 | Train Acc: 78.38% | Valid Loss: 0.4522 | Valid Acc: 79.53%
# Patience: 3/30
# Epoch [34/200] | Train Loss: 0.4673 | Train Acc: 79.10% | Valid Loss: 0.4408 | Valid Acc: 79.01%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [35/200] | Train Loss: 0.4726 | Train Acc: 79.04% | Valid Loss: 0.4597 | Valid Acc: 79.53%
# Patience: 1/30
# Epoch [36/200] | Train Loss: 0.4774 | Train Acc: 78.39% | Valid Loss: 0.4456 | Valid Acc: 75.62%
# Patience: 2/30
# Epoch [37/200] | Train Loss: 0.4640 | Train Acc: 79.46% | Valid Loss: 0.4445 | Valid Acc: 82.40%
# Patience: 3/30
# Epoch [38/200] | Train Loss: 0.4595 | Train Acc: 80.84% | Valid Loss: 0.4235 | Valid Acc: 81.10%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [39/200] | Train Loss: 0.4614 | Train Acc: 78.79% | Valid Loss: 0.4270 | Valid Acc: 80.71%
# Patience: 1/30
# Epoch [40/200] | Train Loss: 0.4502 | Train Acc: 79.76% | Valid Loss: 0.4329 | Valid Acc: 80.58%
# Patience: 2/30
# Epoch [41/200] | Train Loss: 0.4525 | Train Acc: 80.15% | Valid Loss: 0.4140 | Valid Acc: 83.45%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [42/200] | Train Loss: 0.4327 | Train Acc: 81.32% | Valid Loss: 0.4189 | Valid Acc: 78.63%
# Patience: 1/30
# Epoch [43/200] | Train Loss: 0.4441 | Train Acc: 80.82% | Valid Loss: 0.4119 | Valid Acc: 81.23%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [44/200] | Train Loss: 0.4545 | Train Acc: 80.40% | Valid Loss: 0.4239 | Valid Acc: 80.71%
# Patience: 1/30
# Epoch [45/200] | Train Loss: 0.4453 | Train Acc: 80.72% | Valid Loss: 0.4062 | Valid Acc: 80.71%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [46/200] | Train Loss: 0.4349 | Train Acc: 82.41% | Valid Loss: 0.4119 | Valid Acc: 80.96%
# Patience: 1/30
# Epoch [47/200] | Train Loss: 0.4257 | Train Acc: 82.01% | Valid Loss: 0.3904 | Valid Acc: 85.01%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [48/200] | Train Loss: 0.4458 | Train Acc: 79.33% | Valid Loss: 0.4007 | Valid Acc: 83.83%
# Patience: 1/30
# Epoch [49/200] | Train Loss: 0.4316 | Train Acc: 80.78% | Valid Loss: 0.3995 | Valid Acc: 82.54%
# Patience: 2/30
# Epoch [50/200] | Train Loss: 0.4332 | Train Acc: 81.15% | Valid Loss: 0.3910 | Valid Acc: 83.70%
# Patience: 3/30
# Epoch [51/200] | Train Loss: 0.4145 | Train Acc: 82.52% | Valid Loss: 0.3875 | Valid Acc: 80.44%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [52/200] | Train Loss: 0.4306 | Train Acc: 80.65% | Valid Loss: 0.3869 | Valid Acc: 86.18%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [53/200] | Train Loss: 0.4253 | Train Acc: 82.73% | Valid Loss: 0.4015 | Valid Acc: 82.27%
# Patience: 1/30
# Epoch [54/200] | Train Loss: 0.4260 | Train Acc: 80.59% | Valid Loss: 0.3873 | Valid Acc: 85.79%
# Patience: 2/30
# Epoch [55/200] | Train Loss: 0.4238 | Train Acc: 81.14% | Valid Loss: 0.4048 | Valid Acc: 79.92%
# Patience: 3/30
# Epoch [56/200] | Train Loss: 0.4237 | Train Acc: 82.23% | Valid Loss: 0.3872 | Valid Acc: 86.84%
# Patience: 4/30
# Epoch [57/200] | Train Loss: 0.4168 | Train Acc: 81.36% | Valid Loss: 0.3780 | Valid Acc: 85.53%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [58/200] | Train Loss: 0.4078 | Train Acc: 82.46% | Valid Loss: 0.3870 | Valid Acc: 83.31%
# Patience: 1/30
# Epoch [59/200] | Train Loss: 0.4007 | Train Acc: 82.53% | Valid Loss: 0.3848 | Valid Acc: 82.27%
# Patience: 2/30
# Epoch [60/200] | Train Loss: 0.4097 | Train Acc: 82.12% | Valid Loss: 0.3854 | Valid Acc: 80.96%
# Patience: 3/30
# Epoch [61/200] | Train Loss: 0.4087 | Train Acc: 82.76% | Valid Loss: 0.3683 | Valid Acc: 85.53%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [62/200] | Train Loss: 0.3997 | Train Acc: 82.97% | Valid Loss: 0.3762 | Valid Acc: 79.67%
# Patience: 1/30
# Epoch [63/200] | Train Loss: 0.4175 | Train Acc: 81.11% | Valid Loss: 0.3817 | Valid Acc: 82.14%
# Patience: 2/30
# Epoch [64/200] | Train Loss: 0.3996 | Train Acc: 82.26% | Valid Loss: 0.3614 | Valid Acc: 85.79%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [65/200] | Train Loss: 0.3892 | Train Acc: 83.05% | Valid Loss: 0.3579 | Valid Acc: 85.66%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [66/200] | Train Loss: 0.3800 | Train Acc: 83.14% | Valid Loss: 0.3610 | Valid Acc: 82.40%
# Patience: 1/30
# Epoch [67/200] | Train Loss: 0.3817 | Train Acc: 83.34% | Valid Loss: 0.3623 | Valid Acc: 87.61%
# Patience: 2/30
# Epoch [68/200] | Train Loss: 0.4022 | Train Acc: 82.76% | Valid Loss: 0.4002 | Valid Acc: 79.40%
# Patience: 3/30
# Epoch [69/200] | Train Loss: 0.4109 | Train Acc: 82.66% | Valid Loss: 0.3592 | Valid Acc: 86.32%
# Patience: 4/30
# Epoch [70/200] | Train Loss: 0.3867 | Train Acc: 84.20% | Valid Loss: 0.3743 | Valid Acc: 81.36%
# Patience: 5/30
# Epoch [71/200] | Train Loss: 0.4121 | Train Acc: 83.36% | Valid Loss: 0.3667 | Valid Acc: 86.05%
# Patience: 6/30
# Epoch [72/200] | Train Loss: 0.4007 | Train Acc: 82.68% | Valid Loss: 0.3568 | Valid Acc: 86.44%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [73/200] | Train Loss: 0.3966 | Train Acc: 83.79% | Valid Loss: 0.3649 | Valid Acc: 82.79%
# Patience: 1/30
# Epoch [74/200] | Train Loss: 0.3611 | Train Acc: 85.66% | Valid Loss: 0.3628 | Valid Acc: 85.66%
# Patience: 2/30
# Epoch [75/200] | Train Loss: 0.3960 | Train Acc: 83.56% | Valid Loss: 0.3768 | Valid Acc: 80.06%
# Patience: 3/30
# Epoch [76/200] | Train Loss: 0.3917 | Train Acc: 82.47% | Valid Loss: 0.3594 | Valid Acc: 86.05%
# Patience: 4/30
# Epoch [77/200] | Train Loss: 0.3732 | Train Acc: 84.81% | Valid Loss: 0.3404 | Valid Acc: 86.70%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [78/200] | Train Loss: 0.3886 | Train Acc: 83.64% | Valid Loss: 0.3469 | Valid Acc: 83.31%
# Patience: 1/30
# Epoch [79/200] | Train Loss: 0.3803 | Train Acc: 84.48% | Valid Loss: 0.3411 | Valid Acc: 85.53%
# Patience: 2/30
# Epoch [80/200] | Train Loss: 0.3798 | Train Acc: 83.44% | Valid Loss: 0.3540 | Valid Acc: 86.57%
# Patience: 3/30
# Epoch [81/200] | Train Loss: 0.3581 | Train Acc: 85.49% | Valid Loss: 0.3566 | Valid Acc: 81.10%
# Patience: 4/30
# Epoch [82/200] | Train Loss: 0.3669 | Train Acc: 83.41% | Valid Loss: 0.3401 | Valid Acc: 87.09%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [83/200] | Train Loss: 0.3475 | Train Acc: 85.60% | Valid Loss: 0.3512 | Valid Acc: 84.49%
# Patience: 1/30
# Epoch [84/200] | Train Loss: 0.3990 | Train Acc: 82.70% | Valid Loss: 0.3385 | Valid Acc: 87.09%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [85/200] | Train Loss: 0.3663 | Train Acc: 84.33% | Valid Loss: 0.3597 | Valid Acc: 84.49%
# Patience: 1/30
# Epoch [86/200] | Train Loss: 0.3828 | Train Acc: 83.93% | Valid Loss: 0.3289 | Valid Acc: 86.70%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [87/200] | Train Loss: 0.3628 | Train Acc: 84.33% | Valid Loss: 0.3354 | Valid Acc: 85.53%
# Patience: 1/30
# Epoch [88/200] | Train Loss: 0.3736 | Train Acc: 84.08% | Valid Loss: 0.3475 | Valid Acc: 85.40%
# Patience: 2/30
# Epoch [89/200] | Train Loss: 0.3629 | Train Acc: 83.46% | Valid Loss: 0.3422 | Valid Acc: 87.36%
# Patience: 3/30
# Epoch [90/200] | Train Loss: 0.3851 | Train Acc: 83.77% | Valid Loss: 0.3517 | Valid Acc: 86.57%
# Patience: 4/30
# Epoch [91/200] | Train Loss: 0.3777 | Train Acc: 84.92% | Valid Loss: 0.3440 | Valid Acc: 85.53%
# Patience: 5/30
# Epoch [92/200] | Train Loss: 0.3709 | Train Acc: 84.06% | Valid Loss: 0.3373 | Valid Acc: 83.83%
# Patience: 6/30
# Epoch [93/200] | Train Loss: 0.3655 | Train Acc: 85.41% | Valid Loss: 0.3593 | Valid Acc: 84.88%
# Patience: 7/30
# Epoch [94/200] | Train Loss: 0.3656 | Train Acc: 85.26% | Valid Loss: 0.3409 | Valid Acc: 85.53%
# Patience: 8/30
# Epoch [95/200] | Train Loss: 0.3555 | Train Acc: 84.77% | Valid Loss: 0.3330 | Valid Acc: 87.22%
# Patience: 9/30
# Epoch [96/200] | Train Loss: 0.3764 | Train Acc: 83.42% | Valid Loss: 0.3369 | Valid Acc: 85.40%
# Patience: 10/30
# Epoch [97/200] | Train Loss: 0.3646 | Train Acc: 84.66% | Valid Loss: 0.3289 | Valid Acc: 83.70%
# Patience: 11/30
# Epoch [98/200] | Train Loss: 0.3618 | Train Acc: 85.29% | Valid Loss: 0.3235 | Valid Acc: 85.53%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [99/200] | Train Loss: 0.3744 | Train Acc: 84.22% | Valid Loss: 0.3299 | Valid Acc: 84.22%
# Patience: 1/30
# Epoch [100/200] | Train Loss: 0.3663 | Train Acc: 84.65% | Valid Loss: 0.3441 | Valid Acc: 84.22%
# Patience: 2/30
# Epoch [101/200] | Train Loss: 0.3528 | Train Acc: 85.18% | Valid Loss: 0.3416 | Valid Acc: 85.01%
# Patience: 3/30
# Epoch [102/200] | Train Loss: 0.3280 | Train Acc: 86.62% | Valid Loss: 0.3577 | Valid Acc: 83.45%
# Patience: 4/30
# Epoch [103/200] | Train Loss: 0.3649 | Train Acc: 84.83% | Valid Loss: 0.3393 | Valid Acc: 83.97%
# Patience: 5/30
# Epoch [104/200] | Train Loss: 0.3479 | Train Acc: 85.88% | Valid Loss: 0.3200 | Valid Acc: 87.36%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [105/200] | Train Loss: 0.3736 | Train Acc: 85.63% | Valid Loss: 0.3378 | Valid Acc: 87.36%
# Patience: 1/30
# Epoch [106/200] | Train Loss: 0.3633 | Train Acc: 84.27% | Valid Loss: 0.3165 | Valid Acc: 87.88%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [107/200] | Train Loss: 0.3711 | Train Acc: 84.40% | Valid Loss: 0.3128 | Valid Acc: 87.22%
# Valid loss improved. Saving checkpoint to 1D-CNN.pth
# Epoch [108/200] | Train Loss: 0.3493 | Train Acc: 84.87% | Valid Loss: 0.3330 | Valid Acc: 86.57%
# Patience: 1/30
# Epoch [109/200] | Train Loss: 0.3509 | Train Acc: 84.14% | Valid Loss: 0.3287 | Valid Acc: 87.75%
# Patience: 2/30
# Epoch [110/200] | Train Loss: 0.3846 | Train Acc: 84.81% | Valid Loss: 0.3375 | Valid Acc: 87.75%
# Patience: 3/30
# Epoch [111/200] | Train Loss: 0.3617 | Train Acc: 84.55% | Valid Loss: 0.3234 | Valid Acc: 88.40%
# Patience: 4/30
# Epoch [112/200] | Train Loss: 0.3395 | Train Acc: 85.79% | Valid Loss: 0.3307 | Valid Acc: 87.09%
# Patience: 5/30
# Epoch [113/200] | Train Loss: 0.3648 | Train Acc: 85.04% | Valid Loss: 0.3178 | Valid Acc: 87.22%
# Patience: 6/30
# Epoch [114/200] | Train Loss: 0.3520 | Train Acc: 85.65% | Valid Loss: 0.3371 | Valid Acc: 86.57%
# Patience: 7/30
# Epoch [115/200] | Train Loss: 0.3333 | Train Acc: 86.90% | Valid Loss: 0.3247 | Valid Acc: 87.75%
# Patience: 8/30
# Epoch [116/200] | Train Loss: 0.3401 | Train Acc: 85.33% | Valid Loss: 0.3180 | Valid Acc: 87.09%
# Patience: 9/30
# Epoch [117/200] | Train Loss: 0.3372 | Train Acc: 85.65% | Valid Loss: 0.3261 | Valid Acc: 86.57%
# Patience: 10/30
# Epoch [118/200] | Train Loss: 0.3546 | Train Acc: 85.13% | Valid Loss: 0.3230 | Valid Acc: 86.57%
# Patience: 11/30
# Epoch [119/200] | Train Loss: 0.3417 | Train Acc: 84.02% | Valid Loss: 0.3340 | Valid Acc: 87.88%
# Patience: 12/30
# Epoch [120/200] | Train Loss: 0.3622 | Train Acc: 84.44% | Valid Loss: 0.3230 | Valid Acc: 88.40%
# Patience: 13/30
# Epoch [121/200] | Train Loss: 0.3347 | Train Acc: 86.75% | Valid Loss: 0.3314 | Valid Acc: 86.57%
# Patience: 14/30
# Epoch [122/200] | Train Loss: 0.3339 | Train Acc: 85.50% | Valid Loss: 0.3228 | Valid Acc: 87.09%
# Patience: 15/30
# Epoch [123/200] | Train Loss: 0.3215 | Train Acc: 87.11% | Valid Loss: 0.3229 | Valid Acc: 87.22%
# Patience: 16/30
# Epoch [124/200] | Train Loss: 0.3575 | Train Acc: 84.66% | Valid Loss: 0.3304 | Valid Acc: 86.57%
# Patience: 17/30
# Epoch [125/200] | Train Loss: 0.3405 | Train Acc: 86.08% | Valid Loss: 0.3243 | Valid Acc: 87.88%
# Patience: 18/30
# Epoch [126/200] | Train Loss: 0.3430 | Train Acc: 85.35% | Valid Loss: 0.3224 | Valid Acc: 86.70%
# Patience: 19/30
# Epoch [127/200] | Train Loss: 0.3423 | Train Acc: 84.89% | Valid Loss: 0.3252 | Valid Acc: 87.61%
# Patience: 20/30
# Epoch [128/200] | Train Loss: 0.3431 | Train Acc: 86.34% | Valid Loss: 0.3439 | Valid Acc: 87.22%
# Patience: 21/30
# Epoch [129/200] | Train Loss: 0.3331 | Train Acc: 86.11% | Valid Loss: 0.3136 | Valid Acc: 87.22%
# Patience: 22/30
# Epoch [130/200] | Train Loss: 0.3351 | Train Acc: 85.56% | Valid Loss: 0.3293 | Valid Acc: 86.57%
# Patience: 23/30
# Epoch [131/200] | Train Loss: 0.3512 | Train Acc: 85.22% | Valid Loss: 0.3293 | Valid Acc: 87.36%
# Patience: 24/30
# Epoch [132/200] | Train Loss: 0.3411 | Train Acc: 86.26% | Valid Loss: 0.3166 | Valid Acc: 87.88%
# Patience: 25/30
# Epoch [133/200] | Train Loss: 0.3254 | Train Acc: 87.21% | Valid Loss: 0.3295 | Valid Acc: 86.70%
# Patience: 26/30
# Epoch [134/200] | Train Loss: 0.3391 | Train Acc: 85.98% | Valid Loss: 0.3316 | Valid Acc: 86.05%
# Patience: 27/30
# Epoch [135/200] | Train Loss: 0.3351 | Train Acc: 86.89% | Valid Loss: 0.3217 | Valid Acc: 86.05%
# Patience: 28/30
# Epoch [136/200] | Train Loss: 0.3646 | Train Acc: 85.73% | Valid Loss: 0.3255 | Valid Acc: 86.57%
# Patience: 29/30
# Epoch [137/200] | Train Loss: 0.3247 | Train Acc: 86.06% | Valid Loss: 0.3199 | Valid Acc: 86.57%
# Patience: 30/30
# Early Stopping triggered
# Training Complete.

# %% [markdown]
# # **Model Loss & Accuracy**

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

ax1.plot(train_losses, label='Training Loss')
ax1.plot(valid_losses, label='Validation Loss', linestyle='--')
ax1.set_title('Model Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

ax2.plot(train_accs, label='Training Accuracy')
ax2.plot(valid_accs, label='Validation Accuracy', linestyle='--')
ax2.set_title('Model Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.legend()
ax2.grid(True)

plt.show()

# %% [markdown]
# # **Classification Report - Test Set**

# %%
model.load_state_dict(torch.load("1D-CNN.pth"))
model.eval()
print("Best model loaded")

final_preds = []
final_true = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        out = model(X_batch)
        probs = torch.sigmoid(out)
        preds = (probs > 0.5).float()

        final_preds.extend(preds.cpu().numpy())
        final_true.extend(y_batch.cpu().numpy())

print(classification_report(final_true, final_preds, target_names=["Good Posture", "Bad Posture"], zero_division=0))
# Out:
# Best model loaded
#               precision    recall  f1-score   support
#
# Good Posture       0.82      0.90      0.86        41
#  Bad Posture       0.91      0.83      0.87        48
#
#     accuracy                           0.87        89
#    macro avg       0.87      0.87      0.87        89
# weighted avg       0.87      0.87      0.87        89
